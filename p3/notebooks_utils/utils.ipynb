# %% [markdown]
# # **Useful functions for your lab assigments**

# %% [markdown]
# **numpy.argmax: Returns the indices of the maximum values along an axis. See: https://numpy.org/doc/stable/reference/generated/numpy.argmax.html**

# %%
import numpy as np
array = np.random.rand(10)
print ("Sample array")
print (array)
idxmax = np.argmax(array)
print ("Index {} has the highest value ({}) of the array".format(idxmax, array[idxmax]))
# Out:
# Sample array
# [0.02918459 0.79614161 0.95185499 0.45906552 0.5271223  0.17038015
#  0.19131558 0.49755484 0.60040273 0.94830424]
# Index 2 has the highest value (0.9518549866920835) of the array

# %% [markdown]
# **tqdm - Helps estimate the computation time of a loop**

# %%
import tqdm
import time

for i in tqdm.tqdm(range(1000)):
  time.sleep(0.005)
# Out:
# 100%|██████████| 1000/1000 [00:05<00:00, 192.26it/s]
